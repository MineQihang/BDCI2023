# %%
# General imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys, gc, time, warnings, pickle, psutil, random

from math import ceil

from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm

warnings.filterwarnings('ignore')

DIR = "C:/Users/Yipeng/Contest/BDCI2023/code/"
DIR_DATA_RAW = DIR + "data/"
DIR_DATA_PRE = DIR + "data/preprocessed/"
DIR_MODEL = DIR + "model/"
DIR_MODEL_LGB = DIR_MODEL + "lgb/"

# %%
########################### Helpers
#################################################################################
## Seeder
def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)

    
## Multiprocess Runs
def df_parallelize_run(func, t_split):
    num_cores = np.min([N_CORES,len(t_split)])
    pool = Pool(num_cores)
    df = pd.concat(pool.map(func, t_split), axis=1)
    pool.close()
    pool.join()
    return df

# %%
########################### Helper to load data by store ID
#################################################################################
# Read data
def get_data_by_store(store):
    
    # Read and contact basic feature
    df = pd.concat([pd.read_pickle(BASE),
                    pd.read_pickle(PRICE).iloc[:,2:],
                    pd.read_pickle(CALENDAR).iloc[:,2:]],
                    axis=1)
    
    df = df[df['d']>=START_TRAIN]
    
    df = df[df['store_id']==store]

    df2 = pd.read_pickle(MEAN_ENC)[mean_features]
    df2 = df2[df2.index.isin(df.index)]
    
    df3 = pd.read_pickle(LAGS).iloc[:,3:]
    df3 = df3[df3.index.isin(df.index)]
    
    df = pd.concat([df, df2], axis=1)
    del df2
    
    df = pd.concat([df, df3], axis=1)
    del df3

    features = [col for col in list(df) if col not in remove_features]
    df = df[['id','d',TARGET]+features]
    
    df = df.reset_index(drop=True)
    
    return df, features

# Recombine Test set after training
def get_base_test():
    base_test = pd.DataFrame()

    for store_id in STORES_IDS:
        temp_df = pd.read_pickle(processed_data_dir+'test_'+store_id+'.pkl')
        temp_df['store_id'] = store_id
        base_test = pd.concat([base_test, temp_df]).reset_index(drop=True)
    
    return base_test


########################### Helper to make dynamic rolling lags
#################################################################################
def make_lag(LAG_DAY):
    lag_df = base_test[['id','d',TARGET]]
    col_name = 'sales_lag_'+str(LAG_DAY)
    lag_df[col_name] = lag_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(LAG_DAY)).astype(np.float16)
    return lag_df[[col_name]]


def make_lag_roll(LAG_DAY):
    shift_day = LAG_DAY[0]
    roll_wind = LAG_DAY[1]
    lag_df = base_test[['id','d',TARGET]]
    col_name = 'rolling_mean_tmp_'+str(shift_day)+'_'+str(roll_wind)
    lag_df[col_name] = lag_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(shift_day).rolling(roll_wind).mean())
    return lag_df[[col_name]]

# %% [markdown]
# # 1. 加载数据

# %%
import lightgbm as lgb

data_merged = pd.read_pickle(DIR_DATA_PRE + "data_merged.pkl")
data_merged.columns
# Out:
# Index(['store_id', 'sku_id', 'date', 'original_price', 'price_max',
#        'price_min', 'price_mean', 'price_std', 'price_median', 'price_skew',
#        ...
#        'sales_21_pw_mean_change', 'sales_30_pw_mean', 'sales_30_pw_std',
#        'sales_30_pw_mean_change', 'sales_60_pw_mean', 'sales_60_pw_std',
#        'sales_60_pw_mean_change', 'sales_90_pw_mean', 'sales_90_pw_std',
#        'sales_90_pw_mean_change'],
#       dtype='object', length=142)

# %%
lst = []
for day in [1,3,5,7,14,21,30,60,90]:
    lst.append(f"sales_{day}_mean")
    lst.append(f"sales_{day}_std")
    lst.append(f"sales_{day}_mean_change")
data_merged.drop(lst, axis=1, inplace=True)

# %%
X_train = data_merged[data_merged['date'] < pd.to_datetime("2023-08-24")]
X_test = data_merged[(data_merged['date'] >= pd.to_datetime("2023-08-24")) & (data_merged['date'] < pd.to_datetime("2023-08-31"))]
y_train = X_train['quantity']
y_test = X_test['quantity']
X_train = X_train.drop(["quantity", "date"], axis=1)
X_test = X_test.drop(["quantity", "date"], axis=1)

# %%
del data_merged

# %%
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test)

def save_model_callback(model_prefix, period=100):
    def callback(env):
        if env.iteration % period == 0:
            # 保存每轮模型
            model_name = f"{model_prefix}_iteration_{env.iteration}.txt"
            env.model.save_model(model_name)
    return callback

def create_custom_obj_func(original_price):
    def custom_obj_func(preds, train_data):
        labels = train_data.get_label()
        grad = (preds - labels)
        hess = np.ones(len(labels))
        return grad, hess
    return custom_obj_func

# 在创建自定义目标函数时传入额外数据
custom_obj = create_custom_obj_func(X_train['original_price'].values)


lgb_params = {
    'boosting_type': 'gbdt',
    'objective': custom_obj,
    'tweedie_variance_power': 1.1,
    'metric': 'rmse',
    'subsample': 0.5,
    'subsample_freq': 1,
    'learning_rate': 0.015,
    'num_leaves': 2**11-1,
    'min_data_in_leaf': 2**12-1,
    'feature_fraction': 0.5,
    'max_bin': 100,
    'n_estimators': 3000,
    'boost_from_average': False,
    'verbose': -1,
    # 'device': 'gpu'
} 

from lightgbm import log_evaluation, early_stopping

seed_everything(23)

callbacks = [log_evaluation(period=1), early_stopping(stopping_rounds=30), save_model_callback(DIR_MODEL_LGB + 'all', period=100)]

model = lgb.train(lgb_params, train_data, valid_sets=[train_data, test_data], callbacks=callbacks)
# Out:
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	training's rmse: 5.82243	valid_1's rmse: 6.34458
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	training's rmse: 5.81482	valid_1's rmse: 6.32976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	training's rmse: 5.80693	valid_1's rmse: 6.31435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	training's rmse: 5.80021	valid_1's rmse: 6.3005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	training's rmse: 5.79351	valid_1's rmse: 6.28625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	training's rmse: 5.78642	valid_1's rmse: 6.27033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	training's rmse: 5.77961	valid_1's rmse: 6.25639
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	training's rmse: 5.77321	valid_1's rmse: 6.24238
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	training's rmse: 5.76675	valid_1's rmse: 6.22771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	training's rmse: 5.7602	valid_1's rmse: 6.216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	training's rmse: 5.75375	valid_1's rmse: 6.20497
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	training's rmse: 5.74725	valid_1's rmse: 6.1924
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	training's rmse: 5.74128	valid_1's rmse: 6.18024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	training's rmse: 5.73484	valid_1's rmse: 6.16976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	training's rmse: 5.72885	valid_1's rmse: 6.15856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	training's rmse: 5.72326	valid_1's rmse: 6.14677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	training's rmse: 5.71716	valid_1's rmse: 6.13435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	training's rmse: 5.71204	valid_1's rmse: 6.12421
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	training's rmse: 5.70632	valid_1's rmse: 6.11133
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	training's rmse: 5.70166	valid_1's rmse: 6.10187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	training's rmse: 5.69644	valid_1's rmse: 6.09088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	training's rmse: 5.69123	valid_1's rmse: 6.0792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	training's rmse: 5.68592	valid_1's rmse: 6.06873
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	training's rmse: 5.68161	valid_1's rmse: 6.05854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	training's rmse: 5.67613	valid_1's rmse: 6.04843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	training's rmse: 5.67163	valid_1's rmse: 6.03958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	training's rmse: 5.66722	valid_1's rmse: 6.02897
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	training's rmse: 5.66291	valid_1's rmse: 6.01892
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	training's rmse: 5.65826	valid_1's rmse: 6.00869
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	training's rmse: 5.65342	valid_1's rmse: 5.99772
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	training's rmse: 5.64919	valid_1's rmse: 5.98857
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	training's rmse: 5.64476	valid_1's rmse: 5.97851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	training's rmse: 5.64122	valid_1's rmse: 5.96924
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	training's rmse: 5.63679	valid_1's rmse: 5.96115
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	training's rmse: 5.63252	valid_1's rmse: 5.95157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	training's rmse: 5.62874	valid_1's rmse: 5.94316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	training's rmse: 5.62423	valid_1's rmse: 5.93365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	training's rmse: 5.61991	valid_1's rmse: 5.92439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	training's rmse: 5.6161	valid_1's rmse: 5.91616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	training's rmse: 5.61263	valid_1's rmse: 5.90803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	training's rmse: 5.60901	valid_1's rmse: 5.89954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	training's rmse: 5.60534	valid_1's rmse: 5.89098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	training's rmse: 5.60227	valid_1's rmse: 5.88405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	training's rmse: 5.59848	valid_1's rmse: 5.87543
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	training's rmse: 5.59496	valid_1's rmse: 5.86818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	training's rmse: 5.59243	valid_1's rmse: 5.86185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	training's rmse: 5.58974	valid_1's rmse: 5.85486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	training's rmse: 5.58676	valid_1's rmse: 5.84864
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	training's rmse: 5.58323	valid_1's rmse: 5.84176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	training's rmse: 5.57983	valid_1's rmse: 5.83438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	training's rmse: 5.5765	valid_1's rmse: 5.8276
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	training's rmse: 5.57318	valid_1's rmse: 5.81868
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	training's rmse: 5.5699	valid_1's rmse: 5.81193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	training's rmse: 5.56698	valid_1's rmse: 5.80498
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	training's rmse: 5.56455	valid_1's rmse: 5.79871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	training's rmse: 5.5615	valid_1's rmse: 5.7924
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	training's rmse: 5.55847	valid_1's rmse: 5.786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	training's rmse: 5.55562	valid_1's rmse: 5.77934
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	training's rmse: 5.55252	valid_1's rmse: 5.77092
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	training's rmse: 5.5504	valid_1's rmse: 5.76502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	training's rmse: 5.54804	valid_1's rmse: 5.75941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	training's rmse: 5.54499	valid_1's rmse: 5.75504
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	training's rmse: 5.54237	valid_1's rmse: 5.74916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	training's rmse: 5.53941	valid_1's rmse: 5.74254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	training's rmse: 5.53657	valid_1's rmse: 5.73776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	training's rmse: 5.53409	valid_1's rmse: 5.73191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	training's rmse: 5.53212	valid_1's rmse: 5.72592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [162]	training's rmse: 5.53016	valid_1's rmse: 5.72056
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	training's rmse: 5.52788	valid_1's rmse: 5.71468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	training's rmse: 5.52565	valid_1's rmse: 5.70972
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	training's rmse: 5.52355	valid_1's rmse: 5.70425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	training's rmse: 5.52168	valid_1's rmse: 5.69854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	training's rmse: 5.51875	valid_1's rmse: 5.69283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	training's rmse: 5.51627	valid_1's rmse: 5.68877
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [169]	training's rmse: 5.51416	valid_1's rmse: 5.68316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	training's rmse: 5.51184	valid_1's rmse: 5.67793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [171]	training's rmse: 5.50955	valid_1's rmse: 5.67294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	training's rmse: 5.50699	valid_1's rmse: 5.66748
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	training's rmse: 5.50433	valid_1's rmse: 5.662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	training's rmse: 5.50236	valid_1's rmse: 5.65696
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	training's rmse: 5.50017	valid_1's rmse: 5.65223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	training's rmse: 5.49798	valid_1's rmse: 5.64847
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	training's rmse: 5.49603	valid_1's rmse: 5.64435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	training's rmse: 5.4939	valid_1's rmse: 5.64021
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	training's rmse: 5.49128	valid_1's rmse: 5.63433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	training's rmse: 5.48948	valid_1's rmse: 5.62979
# Exception ignored on calling ctypes callback function: <function _log_callback at 0x0000021D9E84AF70>
# Traceback (most recent call last):
#   File "c:\Users\Yipeng\anaconda3\envs\p8_tf214\lib\site-packages\lightgbm\basic.py", line 203, in _log_callback
#     def _log_callback(msg: bytes) -> None:
# KeyboardInterrupt:
# No further splits with positive gain, best gain: -inf
# [181]	training's rmse: 5.48746	valid_1's rmse: 5.62487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	training's rmse: 5.48569	valid_1's rmse: 5.62125

# %%
model.save_model(DIR_MODEL_LGB + 'all.txt')
